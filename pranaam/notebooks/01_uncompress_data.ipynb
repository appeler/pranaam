# %%
# %cd /content/drive/MyDrive/Colab/islampy/
# Out:
# /content/drive/MyDrive/Colab/islampy

# %%
# %ls
# Out:
# data/  islampy.ipynb

# %%
# %ls -ltr data/bihar_lr_caste_muslim.7z
# Out:
# -rw------- 1 root root 36073692 Jan  9 15:50 data/bihar_lr_caste_muslim.7z

# %%
# %cd data/
# Out:
# /content/drive/My Drive/Colab/islampy/data

# %%
!7za e bihar_lr_caste_muslim.7z
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 36073692 bytes (35 MiB)
#
# Extracting archive: bihar_lr_caste_muslim.7z
# --
# Path = bihar_lr_caste_muslim.7z
# Type = 7z
# Physical Size = 36073692
# Headers Size = 154
# Method = LZMA2:24
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       260041734
# Compressed: 36073692

# %%
# %ls
# Out:
# bihar_lr_caste_muslim.7z  bihar_lr_caste_muslim.csv
